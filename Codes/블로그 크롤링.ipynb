# %%
import pandas as pd

# %%
import os
os.chdir('C:\\Users\\최연서\\Documents\\미래에셋증권 빅데이터 페스티벌\\blog crawling')

# %%
df = pd.read_pickle('blog_content_concat_주식어플추천_2020-01-01~2021-08-15_page1~100.pkl')

# %%
df
# Out:
#               date                                        title  \
# 0     2021. 6. 15.      주식 어플 추천 너는 앱 뭐써? 무료체험(MTS, 주식거래, 주식정보)
# 1     2021. 2. 20.                 주식 어플 추천 :: 더리치 앱으로 포트폴리오 짜기
# 2     2021. 1. 30.       미국주식 주식어플추천: 더리치 (+ 사용법 소개, 포트폴리오 공개!)
# 3     2021. 7. 17.  주관적인 주식 어플, 앱 추천 : 인베스팅닷컴, 위불, 더리치, 핀업레이더 등
# 4      2021. 5. 6.                         주식 어플 추천 4가지 설치해 보세요
# ..             ...                                          ...
# 695   2021. 8. 11.     주식 초보, 증권사 주식계좌 만들기! 주식 처음 시작 어렵지않아요 :-)
# 696   2021. 7. 24.                                네이버 가계부 어플 추천
# 697   2021. 5. 21.            캐나다 수수료 없이 어플로 주식 시작하기! 비트코인도 가능!
# 698    2021. 8. 9.                     주식 평단가 계산기 활용 및 물타기의 중요성
# 699  2020. 10. 27.                     유안타증권 티레이더 어플로 해외주식 시작해요
#
#                                                content  \
# 0
# 1    오늘은 주식 포트폴리오 어플을 추천드리려고해요 !\n저는 지금 두가지 증권사를 이용...
# 2    안녕하세요~!\n오늘 포스팅에서는 \n주식투자 하시는 분들께서\n사용하기 좋은 어플...
# ...

# %%
n = 100

print(df.iloc[n,1],'\n')
print(df.iloc[n,2])
# Out:
# 주린이 주식어플추천 주식앱추천
#
# 주식(계좌개설;)을 한 지 두 달 정도가
# 되었다.
# 처음엔 안유명한 주식 유튜브까지 다
# 구독하고 시간이 날 때 마다 봤다.
# 유튜브에 주식 동영상은 엄청 올라 오는데
# 바빠서 못보는 동영상이 생기다 보니
# 스트레스를 엄청 받게 되었다 흑흑😥
#  매일 올라오는 이 많은 정보들을
# 빠짐없이 다 봐야할 거 같고,
# 못보면 거기에 나만 모르는 정보가 있을
# 것만  같고,,,그래서 다 봐야할 거 같은
#  이상한 강박증이 생겨 잠도 많이 못잤다ㅠㅠ
# 이러다가
# ⭐핵심적이고 시간 안잡아먹는 거⭐는
# 없을까 생각하다 유명한 주식어플들을
# 받아서 사용해봤다.
# 결론은 아주아주 만족이다👍
# 지금 사용하는 건 이 4가지 주식어플이다..
# .
# 1.증권플러스 -일단 화면이 깔끔하고 뉴스도 깔끔하게 정리되어 있기 때문에 손이 자주 간다.
# -투자칼럼도 있어서 한번씩 보면 재밌다⭐또  증권플러스에서 제일 좋은 점은
#  등락율이 높은 분야에 대한 순위가 뜨고
#  또 그 분야에 어떤 종목들이 있는지,
# 또 그 옆에 종목들의 차트를 간단하게
# 보여주어 너무 좋다👍👍
# 2.주식창 흠 첫 화면부터 뭔가 사용하고 싶지 않게 생겼다,,,,,주식창 쏠2,,,
# 그래도 안 지우고 있는 이유는 이 때문이다.
# ⭐여러 개의 패턴종류를 보여주고 그 패턴에 맞는 게 어떤 종목이 있는지 보여준다.패턴 공부하기에 좋을듯 하다😁
# .
# .
# 3.우먼스탁유튜브에서 우먼경제TV를 보고 설명을 잘해주셔서 어플까지 받게되었다😁
# 처음에는 뭘 봐야되지,,,했는데 간단해서 금방 적응된다.
# 이 어플은 아직 유명하지 않아서  체계화되어 있지는 않지만
# 좋은 점이 직접 정리해서 올려주는 자료들이 정성이 많이 느껴지고 자세해서 좋다.⭐매일 시황이나 특징주 분석 등등 이렇게 정리해서
# 올려주시는데 깔끔하니 너무 좋다👍
# 하루에 1.2개 올려주시는데 자료가 자세하고 깔끔해서 이것만 봐도 될 거 같은 느낌?😁
# .
# .
# ...
